# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # load the data

# %%
data = pd.read_csv("data/source/Contributions_to_Financial_Intermediary_Funds.csv")

# %%
data.head()
# Out:
#    As of Date                    Fund Name   Donor Name Donor Country Code  \
# 0  12/31/2013  Global Environment Facility      Ireland                 IE
# 1  12/31/2013  Global Environment Facility      Austria                 AT
# 2  12/31/2013  Global Environment Facility        Japan                 JP
# 3  12/31/2013  Global Environment Facility  New Zealand                 NZ
# 4  12/31/2013  Global Environment Facility  Switzerland                 CH
#
#   Receipt Type Receipt Quarter  Calendar Year Receipt Currency  \
# 0         Cash         OCT-DEC           2011              EUR
# 1         Note         OCT-DEC           2011              EUR
# 2         Note         OCT-DEC           2011              JPY
# 3         Note         OCT-DEC           2011              NZD
# 4         Note         JAN-MAR           2012              CHF
#
#    Receipt Amount Contribution Type Sub Account Amount in USD  \
# 0    1.420000e+06             Grant        GF05   $1916858.01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3155 entries, 0 to 3154
# Data columns (total 13 columns):
# As of Date            3155 non-null object
# Fund Name             3155 non-null object
# Donor Name            3155 non-null object
# Donor Country Code    2796 non-null object
# Receipt Type          3155 non-null object
# Receipt Quarter       3155 non-null object
# Calendar Year         3155 non-null int64
# Receipt Currency      3155 non-null object
# Receipt Amount        3155 non-null float64
# Contribution Type     3155 non-null object
# Sub Account           1147 non-null object
# Amount in USD         3155 non-null object
# Sector/Theme          3155 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 320.5+ KB

# %% [markdown]
# # Analysis
# ## who's the biggest donor?

# %%
data['Amount in USD'].sum()
# Out:
# '$1916858.01$14360460.00$1556532.55$1890752.00$33224196.53$16090642.72$8634013.28$35283600.00$27207780.00$1606920.00$117567937.50$2000894.28$2362703.68$26085937.50$53930000.00$3445000.00$19486500.00$22215600.00$82383000.00$1479519.00$35890000.00$9689687.00$9689687.00$9689759.66$16400000.00$3215502.05$1705985.71$5400200.00$3333334.00$3333333.00$3333333.00$10020000.00$1000000.00$10020000.00$10020000.00$2700100.00$4000000.00$40949735.75$40949735.75$40949735.70$5420000.00$5420000.00$5410000.00$4000000.00$10000000.00$5886577.42$5886577.43$5886577.42$42536324.79$42536324.79$37926626.72$13433333.00$13433333.00$13433334.00$5400200.00$4000000.00$54227974.40$30000000.00$10000000.00$10000000.00$5480000.00$5400200.00$37740000.00$55000000.00$55000000.00$500000000.00$55000000.00$5400200.00$1500000.00$1500000.00$1500000.00$65355746.00$65355746.00$65355746.00$4000000.00$500000.00$500000.00$5886888.29$2943444.14$4415166.22$4415166.22$10690000.00$7105643.00$7105643.00$7105643.00$500000.00$675025.00$67
# ...

# %%
data['Amount in USD'] = pd.to_numeric(data['Amount in USD'], errors="coerce")

# %%
data.head()
# Out:
#    As of Date                    Fund Name   Donor Name Donor Country Code  \
# 0  12/31/2013  Global Environment Facility      Ireland                 IE
# 1  12/31/2013  Global Environment Facility      Austria                 AT
# 2  12/31/2013  Global Environment Facility        Japan                 JP
# 3  12/31/2013  Global Environment Facility  New Zealand                 NZ
# 4  12/31/2013  Global Environment Facility  Switzerland                 CH
#
#   Receipt Type Receipt Quarter  Calendar Year Receipt Currency  \
# 0         Cash         OCT-DEC           2011              EUR
# 1         Note         OCT-DEC           2011              EUR
# 2         Note         OCT-DEC           2011              JPY
# 3         Note         OCT-DEC           2011              NZD
# 4         Note         JAN-MAR           2012              CHF
#
#    Receipt Amount Contribution Type Sub Account  Amount in USD  \
# 0    1.420000e+06             Grant        GF05            NaN
# ...

# %%
data['Sector/Theme'].value_counts().reset_index().head()
# Out:
#                            index  Sector/Theme
# 0     Environment/Climate Change          1220
# 1                         Health           927
# 2  Agriculture and Food Security           639
# 3                          Other           294
# 4                      Education            44

# %%
data['Donor Name'].value_counts().reset_index().head(10)
# Out:
#                index  Donor Name
# 0      United States         230
# 1     United Kingdom         208
# 2            Germany         161
# 3             Norway         155
# 4          Australia         134
# 5  GFATM Secretariat         125
# 6             Canada         116
# 7        Switzerland         110
# 8        Netherlands         109
# 9             France         109

# %%
data['Calendar Year'].value_counts().reset_index().head(10)
# Out:
#    index  Calendar Year
# 0   2013            435
# 1   2012            400
# 2   2011            330
# 3   2010            283
# 4   2009            239
# 5   2008            210
# 6   2006            190
# 7   2007            184
# 8   2003            143
# 9   1999            133

# %%
yearly_numbers = data['Calendar Year'].value_counts().reset_index()

# %%
yearly_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
# index            23 non-null int64
# Calendar Year    23 non-null int64
# dtypes: int64(2)
# memory usage: 440.0 bytes

# %%
data.head(10)
# Out:
#    As of Date                    Fund Name   Donor Name Donor Country Code  \
# 0  12/31/2013  Global Environment Facility      Ireland                 IE
# 1  12/31/2013  Global Environment Facility      Austria                 AT
# 2  12/31/2013  Global Environment Facility        Japan                 JP
# 3  12/31/2013  Global Environment Facility  New Zealand                 NZ
# 4  12/31/2013  Global Environment Facility  Switzerland                 CH
# 5  12/31/2013  Global Environment Facility        Italy                 IT
# 6  12/31/2013  Global Environment Facility        Italy                 IT
# 7  12/31/2013  Global Environment Facility      Belgium                 BE
# 8  12/31/2013  Global Environment Facility  Netherlands                 NL
# 9  12/31/2013  Global Environment Facility     Slovenia                 SI
#
#   Receipt Type Receipt Quarter  Calendar Year Receipt Currency  \
# 0         Cash         OCT-DEC           2011              EUR
# ...

# %%
chart = yearly_numbers['Calendar Year'].plot.barh()
chart.set_yticklabels(yearly_numbers['index'])
